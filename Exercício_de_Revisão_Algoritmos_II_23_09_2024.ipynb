# %% [markdown]
# <a href="https://colab.research.google.com/github/henrique-furtado47/Algoritmos-python/blob/main/Exerc%C3%ADcio_de_Revis%C3%A3o_Algoritmos_II_23_09_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Adivinhe a palavra!
import random
palavras=['Computador', 'Bolacha', 'Monitor', 'Teclado', 'Mouse', 'Python', 'Javascript']
palavras_de_animo=['Bahhh, você não acertou dessa vez.', 'Na próxima vai', 'Essa foi quase hein.', 'Pensa bem viu.', 'Você consegue, eu confio!']

def palavra():
  i=random.randrange(len(palavras))
  palavra=palavras[i]
  palavra=str.lower(palavra)
  return palavra

def palavra_de_animo():
  palavra_de_animo=random.choice(palavras_de_animo)
  return palavra_de_animo

def embaralhar_palavra(palavra):
  palavra_lista=list(palavra)
  random.shuffle(palavra_lista)
  palavra_embaralhada=''.join(palavra_lista)
  return palavra_embaralhada

def jogo():
  tentativas=5
  tentativa_i=0
  palavra_certa=palavra()
  print(f"""
  Bem vindo ao O JOGO!!

  Você tem 5 tentativas para acertar a palavra embaralhada. Boa sorte!!
  A palavra embaralhada é *{embaralhar_palavra(palavra_certa)}*
  """)
  while tentativas>0:
    tentativa=str.lower(input(f"Digite sua {tentativa_i+1}º tentativa: "))
    tentativa_i+=1
    tentativas-=1
    if tentativa==palavra_certa:
      print(f"\nParabéns!!! Você acertou em {tentativa_i} tentativas!!!")
      break
    else:
      print(palavra_de_animo())
      print(f"Você ainda tem {tentativas} tentativas\n")
  if tentativas==0:
    print(f"\nVocê perdeu :(, a palavra certa era {palavra_certa}")
jogo()
# Out:
#   Bem vindo ao O JOGO!!
#
#   Você tem 5 tentativas para acertar a palavra embaralhada. Boa sorte!!
#   A palavra embaralhada é *onthyp*
#
# Digite sua 1º tentativa:
# Você consegue, eu confio!
# Você ainda tem 4 tentativas
#
# Digite sua 2º tentativa:
# Na próxima vai
# Você ainda tem 3 tentativas
#
# Digite sua 3º tentativa: python
#
# Parabéns!!! Você acertou em 3 tentativas!!!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Adivinhe a palavra!
import random
temas = {
    "Países": {
        "Curtas": [
            "Cuba", "Peru", "Laos", "Mali",
            "Iraque", "Togo", "Benin", "Djibuti",
            "Japão", "Omã"
        ],
        "Medias": [
            "Colômbia", "Uruguai", "Japão", "Egito",
            "México", "Itália", "Suécia", "Chile",
            "Índia", "Grécia"
        ],
        "Longas": [
            "Azerbaijão", "Malásia", "República Checa", "Estados Unidos",
            "Nova Zelândia", "Madagascar", "El Salvador", "Quirguistão",
            "Paraguai", "São Tomé e Príncipe"
        ]
    },
    "Times": {
        "Curtas": [
            "Vasco", "Ajax", "Lyon", "Milan",
            "Nice", "Leeds", "Inter", "Celta",
            "Porto", "Flamengo"
        ],
        "Medias": [
            "Flamengo", "Santos", "Inter de Milão", "Arsenal",
            "Milan", "Liverpool", "Lyon", "Boca Juniors",
            "Roma", "Benfica"
        ],
        "Longas": [
            "Borussia Dortmund", "Chelsea Football Club", "Atlético Mineiro",
            "Club Atlético River Plate", "Manchester City", "Paris Saint-Germain",
            "Sport Lisboa e Benfica", "Real Madrid CF", "São Paulo Futebol Clube",
            "Barcelona Sporting Club"
        ]
    },
    "Cores": {
        "Curtas": [
            "Azul", "Vermelho", "Cinza", "Verde",
            "Ouro", "Rosa", "Preto", "Marrom",
            "Amarelo", "Lilás"
        ],
        "Medias": [
            "Ciano", "Magenta", "Lila", "Coral",
            "Beje", "Púrpura", "Rosa", "Verde",
            "Preto", "Branco"
        ],
        "Longas": [
            "Ametista", "Carminha", "Turquesa", "Amarelo-ouro",
            "Verde-lima", "Azul-escuro", "Laranja-vivo", "Violeta-claro",
            "Verde-musgo", "Marrom-escuro"
        ]
    },
    "Objetos": {
        "Curtas": [
            "Copo", "Faca", "Mapa", "Bola",
            "Capa", "Lápis", "Caixa", "Rede",
            "Saco", "Chave"
        ],
        "Medias": [
            "Cadeira", "Mesa", "Sofá", "Luminária",
            "Ventilador", "Garrafa", "Livro", "Prato",
            "Toalha", "Caneta"
        ],
        "Longas": [
            "Estetoscópio", "Refrigerador", "Computador", "Calculadora",
            "Televisão", "Microondas", "Aparelho de som", "Chaleira elétrica",
            "Secador de cabelo", "Aspirador de pó"
        ]
    },
    "Tecnologia": {
        "Curtas": [
            "USB", "DVD", "VR", "API",
            "LAN", "PC", "App", "Bot",
            "LED", "RAM"
        ],
        "Medias": [
            "Tablet", "Notebook", "Modem", "Teclado",
            "Monitor", "Mouse", "Chip", "Placa-mãe",
            "Headset", "Router"
        ],
        "Longas": [
            "Computador", "Smartphone", "Impressora", "Microcomputador",
            "Televisão inteligente", "Armazenamento em nuvem", "Assistente virtual",
            "Dispositivo portátil", "Carregador solar", "Rede sem fio"
        ]
    }
}

palavras_de_animo=['Bahhh, você não acertou dessa vez.', 'Na próxima vai', 'Essa foi quase hein.', 'Pensa bem viu.', 'Você consegue, eu confio!']
palavra_de_animo=random.choice(palavras_de_animo)
def tema():
  tema=int(input("""Escolha o tema:
  1- Países
  2- Cores
  3- Times
  4- Objetos
  5- Tecnologia\n"""))
  return tema

def dificuldade():
  dificuldade=int(input("""Escolha a dificuldade:
  1- Fácil
  2- Médio
  3- Díficil\n"""))
  return dificuldade

def palavra():
  tema_escolha=tema()
  dificuldade_escolha=dificuldade()
  tema_str=''
  if tema_escolha==1:
    tema_str='Países'
  elif tema_escolha==2:
    tema_str='Cores'
  elif tema_escolha==3:
    tema_str='Times'
  elif tema_escolha==4:
    tema_str='Objetos'
  elif tema_escolha==5:
    tema_str='Tecnologia'

  if dificuldade_escolha == 1:
    dificuldade_str='Curtas'
  elif dificuldade_escolha == 2:
    dificuldade_str='Medias'
  elif dificuldade_escolha == 3:
    dificuldade_str= 'Longas'
  palavra=(random.choice(temas[tema_str][dificuldade_str]))
  palavra=str.lower(palavra)
  return palavra

def embaralhar_palavra(palavra):
  palavra_lista=list(palavra)
  random.shuffle(palavra_lista)
  palavra_embaralhada=''.join(palavra_lista)
  return palavra_embaralhada

def jogo():
  tentativas=5
  tentativa_i=0
  palavra_certa=palavra()
  print(f"""
  \nBem vindo ao O JOGO!!

  Você tem 5 tentativas para acertar a palavra embaralhada. Boa sorte!!
  A palavra embaralhada é *{embaralhar_palavra(palavra_certa)}*
  """)
  while tentativas>0:
    tentativa=str.lower(input(f"Digite sua {tentativa_i+1}º tentativa: "))
    tentativa_i+=1
    tentativas-=1
    if tentativa==palavra_certa:
      print(f"\nParabéns!!! Você acertou em {tentativa_i} tentativas!!!")
      break
    else:
      print(palavra_de_animo)
      print(f"Você ainda tem {tentativas} tentativas\n")
  if tentativas==0:
    print(f"\nVocê perdeu :(, a palavra certa era {palavra_certa}")

# %%
jogo()
# Out:
# Escolha o tema:
#   1- Países
#   2- Cores
#   3- Times
#   4- Objetos
#   5- Tecnologia
# 3
# Escolha a dificuldade:
#   1- Fácil
#   2- Médio
#   3- Díficil
# 1
#
#
# Bem vindo ao O JOGO!!
#
#   Você tem 5 tentativas para acertar a palavra embaralhada. Boa sorte!!
#   A palavra embaralhada é *liman*
#
# Digite sua 1º tentativa: milan
#
# Parabéns!!! Você acertou em 1 tentativas!!!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dados = [
    "2024-09-01: Máxima=28, Mínima=18, Chuva=0.00mm",
    "2024-09-02: Máxima=26, Mínima=17, Chuva=5.20mm",
    "2024-09-03: Máxima=30, Mínima=19, Chuva=0.00mm",
    "2024-09-04: Máxima=27, Mínima=18, Chuva=0.00mm",
    "2024-09-05: Máxima=25, Mínima=16, Chuva=12.50mm",
    "2024-09-06: Máxima=29, Mínima=20, Chuva=0.00mm",
    "2024-09-07: Máxima=31, Mínima=21, Chuva=0.00mm",
    "2024-09-08: Máxima=28, Mínima=19, Chuva=3.00mm",
    "2024-09-09: Máxima=27, Mínima=18, Chuva=7.00mm",
    "2024-09-10: Máxima=26, Mínima=17, Chuva=0.00mm",
    "2024-09-11: Máxima=24, Mínima=16, Chuva=10.00mm",
    "2024-09-12: Máxima=30, Mínima=19, Chuva=0.00mm",
    "2024-09-13: Máxima=29, Mínima=20, Chuva=2.50mm",
    "2024-09-14: Máxima=26, Mínima=18, Chuva=8.00mm",
    "2024-09-15: Máxima=27, Mínima=19, Chuva=0.00mm",
    "2024-09-16: Máxima=28, Mínima=20, Chuva=0.00mm",
    "2024-09-17: Máxima=25, Mínima=16, Chuva=4.00mm",
    "2024-09-18: Máxima=30, Mínima=21, Chuva=0.00mm",
    "2024-09-19: Máxima=29, Mínima=20, Chuva=1.00mm",
    "2024-09-20: Máxima=28, Mínima=19, Chuva=6.00mm",
    "2024-09-21: Máxima=27, Mínima=18, Chuva=0.00mm",
    "2024-09-22: Máxima=26, Mínima=17, Chuva=0.00mm",
    "2024-09-23: Máxima=25, Mínima=16, Chuva=9.00mm",
    "2024-09-24: Máxima=31, Mínima=21, Chuva=0.00mm",
    "2024-09-25: Máxima=30, Mínima=20, Chuva=3.50mm",
    "2024-09-26: Máxima=29, Mínima=19, Chuva=0.00mm",
    "2024-09-27: Máxima=27, Mínima=18, Chuva=5.00mm",
    "2024-09-28: Máxima=28, Mínima=20, Chuva=0.00mm",
    "2024-09-29: Máxima=26, Mínima=17, Chuva=2.00mm",
    "2024-09-30: Máxima=30, Mínima=19, Chuva=0.00mm",
]

def analisa_meteorologia(dados):
  datas=[]
  maximas=[]
  minimas=[]
  chuvas=[]
  for i in dados:
    datas.append(int(i[8:10]))
    maximas.append(int(i[19:21]))
    minimas.append(int(i[30:32]))
    chuvas.append(float(i[40:44]))

  media_maxima=sum(maximas)/len(maximas)
  media_minima=sum(minimas)/len(minimas)

  id_dia_min=minimas.index(min(minimas))
  dia_min=datas[id_dia_min]

  id_dia_chuva=chuvas.index(max(chuvas))
  dia_chuva=datas[id_dia_chuva]

  maior_que_30=[]

  for i in range(len(datas)):
    if chuvas[i]==0 and maximas[i]>30:
      maior_que_30.append(datas[i])

  string_dia=", ".join(map(str, maior_que_30))
  print(f"""Média de Temperatura Máxima:{media_maxima: .2f}
        Média de Temperatura Mínima: {media_minima:.2f}
        Dia com maior precipitação: {dia_chuva}
        Dia com menor temperatura: {dia_min}
        Dias com a temperatura maior que 30º e sem chuva: {string_dia}""")

analisa_meteorologia(dados)
# Out:
# Média de Temperatura Máxima: 27.73
#         Média de Temperatura Mínima: 18.53
#         Dia com maior precipitação: 5
#         Dia com menor temperatura: 5
#         Dias com a temperatura maior que 30º e sem chuva: 7, 24
